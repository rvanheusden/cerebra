# %%
import pandas as pd
import numpy as np
import math
import os

# %%
cwd = '/Users/lincoln.harris/code/cerebra/cerebra/wrkdir/'
muts_path = cwd + 'geneSearch_tumorExome/'

mutationsDF = pd.DataFrame(columns=['patient', 'AKT1_mut', 'ALK_mut', 'BAP1_mut', 'BRAF_mut', 'DDR2_mut', 
        'DROSHA_mut', 'EGFR_mut', 'ERBB2_mut', 'ERBB4_mut', 'FGFR2_mut', 'GRIN2A_mut', 'HIF1a_mut', 'KDR_mut', 
        'KEAP1_mut', 'KRAS_mut', 'MAP2K1_mut', 'MAP2K2_mut', 'MYCL_mut', 'NFE2L2_mut', 'NKX2-1_mut', 'NOTCH1_mut',
        'PIK3CB_mut', 'PTPN13_mut', 'PTPRT_mut', 'RAD21_mut', 'RB1_mut', 'RBM10_mut', 'SMARCA4_mut', 
        'SOX2_mut', 'STK11_mut', 'TP63_mut'])

genesList = ['AKT1', 'ALK', 'BAP1', 'BRAF', 'DDR2', 'DROSHA', 'EGFR', 'ERBB2', 'ERBB4', 'FGFR2', 'GRIN2A',
            'HIF1a', 'KDR', 'KEAP1', 'KRAS', 'MAP2K1', 'MAP2K2', 'MYCL', 'NFE2L2', 'NKX2-1', 'NOTCH1', 'PIK3CB',
            'PTPN13', 'PTPRT', 'RAD21', 'RB1', 'RBM10', 'SMARCA4', 'SOX2', 'STK11', 'TP63']

# %%
# fill in EGFR first
EGFR_path = muts_path + 'EGFR_tumorExome_AA.csv'
EGFR_df = pd.read_csv(EGFR_path, header=None, names=['patient', 'mutations'])
mutationsDF['patient'] = EGFR_df['patient']
mutationsDF['EGFR_mut'] = EGFR_df['mutations'] 
mutationsDF
# Out:
#          patient AKT1_mut ALK_mut BAP1_mut BRAF_mut DDR2_mut DROSHA_mut  \
# 0   TH171_E3.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 1   TH116_E2.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 2   TH179_E1.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 3   TH231_E1.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 4   TH226_E3.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 5   TH187_E3.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 6   TH155_E5.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 7   TH172_E3.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 8   TH169_E4.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 9   TH220_E2.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 10  TH067_E7.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# 11  TH169_E2.vcf      NaN     NaN      NaN      NaN      NaN        NaN
# ...

# %%
mutationsDF['patient'] = mutationsDF['patient'].str.strip('.vcf')
mutationsDF
# Out:
#      patient AKT1_mut ALK_mut BAP1_mut BRAF_mut DDR2_mut DROSHA_mut  \
# 0   TH171_E3      NaN     NaN      NaN      NaN      NaN        NaN
# 1   TH116_E2      NaN     NaN      NaN      NaN      NaN        NaN
# 2   TH179_E1      NaN     NaN      NaN      NaN      NaN        NaN
# 3   TH231_E1      NaN     NaN      NaN      NaN      NaN        NaN
# 4   TH226_E3      NaN     NaN      NaN      NaN      NaN        NaN
# 5   TH187_E3      NaN     NaN      NaN      NaN      NaN        NaN
# 6   TH155_E5      NaN     NaN      NaN      NaN      NaN        NaN
# 7   TH172_E3      NaN     NaN      NaN      NaN      NaN        NaN
# 8   TH169_E4      NaN     NaN      NaN      NaN      NaN        NaN
# 9   TH220_E2      NaN     NaN      NaN      NaN      NaN        NaN
# 10  TH067_E7      NaN     NaN      NaN      NaN      NaN        NaN
# 11  TH169_E2      NaN     NaN      NaN      NaN      NaN        NaN
# 12  TH208_E4      NaN     NaN      NaN      NaN      NaN        NaN
# ...

# %%
def mutations_df_fill_in(GOI, GOI_df, mutationsDF_):
    """ creates a cell-wise dataframe with mutations to each GOI """
    mutName = GOI + '_mut'
    for i in range(0,len(mutationsDF_.index)):
        currPatient = mutationsDF_['patient'][i]

        rightIndex = GOI_df['patient'] == currPatient
        rightRow = GOI_df[rightIndex]
    
        rightPatient = rightRow['patient']
        rightPatient = str(rightPatient).split()[1]
    
        rightMutStr = rightRow['mutations']
        rightMutSplit = str(rightMutStr).split()
        
        j = 1
        rightMutClean = []
        while rightMutSplit[j] != 'Name:':
            rightMutClean.append(rightMutSplit[j])
            j += 1
            
        mutationsDF_[mutName][i] = rightMutClean

# %%
def remove_extra_characters_mutations_df(GOI, mutationsDF_):
    """ converting df cols from lists to strings """
    mutName = GOI + '_mut'

    t = mutationsDF_.applymap(str)
    t[mutName] = t[mutName].str.replace("[", "")
    t[mutName] = t[mutName].str.replace("]", "")
    t[mutName] = t[mutName].str.replace("'", "")
    t[mutName] = t[mutName].str.replace('"', '')
    t[mutName] = t[mutName].str.replace(" ", "")
    
    return(t)

# %%
# now fill in everything else
for gene in genesList:
        gene_path = muts_path + gene + '_tumorExome_AA.csv'
        gene_df = pd.read_csv(gene_path, header=None, names=['patient', 'mutations'])
        gene_df['patient'] = gene_df['patient'].str.strip('.vcf')
        mutations_df_fill_in(gene, gene_df, mutationsDF)
        mutationsDF = remove_extra_characters_mutations_df(gene, mutationsDF)
mutationsDF
# Out:
#      patient AKT1_mut ALK_mut BAP1_mut BRAF_mut DDR2_mut DROSHA_mut  \
# 0   TH171_E3
# 1   TH116_E2
# 2   TH179_E1                              V600E
# 3   TH231_E1
# 4   TH226_E3
# 5   TH187_E3
# 6   TH155_E5
# 7   TH172_E3
# 8   TH169_E4
# 9   TH220_E2
# 10  TH067_E7
# 11  TH169_E2
# 12  TH208_E4
# 13  TH210_E1
# 14  TH205_E2
# 15  TH067_E4
# 16  TH238_E1
# 17  TH208_E3
#
#                                  EGFR_mut ERBB2_mut ERBB4_mut  ... PIK3CB_mut  \
# 0                                                              ...
# 1                                   L858R                      ...
# 2                                                              ...
# 3                                                              ...
# 4   E746_A750delELREA,,E746_T751delELREAT                      ...
# 5                                                              ...
# 6                                   K754E                      ...
# ...

# %%
# read in patientMetadata
metaPATH = '/Users/lincoln.harris/Desktop/LAUD_important_shit/metadata_all_cells_4.10.19.csv'
patientMetadata = pd.read_csv(metaPATH)
patientMetadata = patientMetadata.drop([0,1]) # first two rows are wierd
patientMetadata
# Out:
#            Unnamed: 0  nGene   nReads     orig.ident well       plate  \
# 2      A10_1001000408   7085   602263  SeuratProject  A10  1001000408
# 3      A10_1001000410   1914   185720  SeuratProject  A10  1001000410
# 4      A10_1001000412   7274   914254  SeuratProject  A10  1001000412
# 5         A10_B000420   2464   101565  SeuratProject  A10     B000420
# 6         A10_B000422   3424   748360  SeuratProject  A10     B000422
# 7         A10_B000580   3984  3184663  SeuratProject  A10     B000580
# 8         A10_B000863   1093   391731  SeuratProject  A10     B000863
# 9         A10_B001007    717   399863  SeuratProject  A10     B001007
# 10        A10_B001008   3483   993763  SeuratProject  A10     B001008
# 11        A10_B001010   1911   730050  SeuratProject  A10     B001010
# 12        A10_B001470   2454   141655  SeuratProject  A10     B001470
# 13        A10_B001474   1999   165042  SeuratProject  A10     B001474
# ...

# %%
# init the summary table
cols = ['patient', 'clinical_driver_gene', 'clinical_mutation', 'coverage_to_ROI', 'clin_mut_found_bool', 
        'mutations_found_AKT1', 'mutations_found_ALK', 'mutations_found_BAP1', 'mutations_found_BRAF', 
        'mutations_found_DDR2', 'mutations_found_DROSHA', 'mutations_found_EGFR', 'mutations_found_ERBB2',
        'mutations_found_ERBB4', 'mutations_found_FGFR2', 'mutations_found_GRIN2A','mutations_found_HIF1a', 
        'mutations_found_KDR', 'mutations_found_KEAP1', 'mutations_found_KRAS', 'mutations_found_MAP2K1', 
        'mutations_found_MAP2K2', 'mutations_found_MYCL', 'mutations_found_NFE2L2', 'mutations_found_NKX21',
        'mutations_found_NOTCH1','mutations_found_PIK3CB', 'mutations_found_PTPN13', 'mutations_found_PTPRT',
        'mutations_found_RAD21', 'mutations_found_RB1', 'mutations_found_RBM10',
        'mutations_found_SMARCA4', 'mutations_found_SOX2', 'mutations_found_STK11',
        'mutations_found_TP63']

summaryTable = pd.DataFrame(columns=cols)
summaryTable['patient'] = mutationsDF['patient']
summaryTable
# Out:
#      patient clinical_driver_gene clinical_mutation coverage_to_ROI  \
# 0   TH171_E3                  NaN               NaN             NaN
# 1   TH116_E2                  NaN               NaN             NaN
# 2   TH179_E1                  NaN               NaN             NaN
# 3   TH231_E1                  NaN               NaN             NaN
# 4   TH226_E3                  NaN               NaN             NaN
# 5   TH187_E3                  NaN               NaN             NaN
# 6   TH155_E5                  NaN               NaN             NaN
# 7   TH172_E3                  NaN               NaN             NaN
# 8   TH169_E4                  NaN               NaN             NaN
# 9   TH220_E2                  NaN               NaN             NaN
# 10  TH067_E7                  NaN               NaN             NaN
# 11  TH169_E2                  NaN               NaN             NaN
# 12  TH208_E4                  NaN               NaN             NaN
# ...

# %%
def generic_summary_table_fill_in(metaField, summaryField, summaryTable_, patientMetadata_):
    """ fills in a given metadata field in summaryTable_ """
    for i in range(0,len(summaryTable_.index)):
        currPatient = summaryTable_['patient'][i]
        currPatient = currPatient.split('_')[0]
        index_to_keep = patientMetadata_['patient_id'] == currPatient
        keepRow = patientMetadata_[index_to_keep]
        try:
            currField = list(keepRow[metaField])[0]
            summaryTable_[summaryField][i] = currField
        except IndexError:
            continue

# %%
# fill in various metadata cols
generic_summary_table_fill_in('driver_gene', 'clinical_driver_gene', summaryTable, patientMetadata)
generic_summary_table_fill_in('driver_mutation', 'clinical_mutation', summaryTable, patientMetadata)
summaryTable
# Out:
#      patient clinical_driver_gene clinical_mutation coverage_to_ROI  \
# 0   TH171_E3                  ALK            fusion             NaN
# 1   TH116_E2                  NaN               NaN             NaN
# 2   TH179_E1                 BRAF             V600E             NaN
# 3   TH231_E1                  ALK            fusion             NaN
# 4   TH226_E3                 EGFR             del19             NaN
# 5   TH187_E3                  NaN               NaN             NaN
# 6   TH155_E5                 EGFR             del19             NaN
# 7   TH172_E3                  NaN               NaN             NaN
# 8   TH169_E4                 EGFR             del19             NaN
# 9   TH220_E2                  ALK            fusion             NaN
# 10  TH067_E7                 EGFR             del19             NaN
# 11  TH169_E2                 EGFR             del19             NaN
# 12  TH208_E4                  NaN               NaN             NaN
# ...

# %%
# fill in mutations found col 
for gene in genesList:
    summary_col = 'mutations_found_' + gene
    mutsdf_col = gene + '_mut'
    summaryTable[summary_col] = mutationsDF[mutsdf_col]
summaryTable
# Out:
#      patient clinical_driver_gene clinical_mutation coverage_to_ROI  \
# 0   TH171_E3                  ALK            fusion             NaN
# 1   TH116_E2                  NaN               NaN             NaN
# 2   TH179_E1                 BRAF             V600E             NaN
# 3   TH231_E1                  ALK            fusion             NaN
# 4   TH226_E3                 EGFR             del19             NaN
# 5   TH187_E3                  NaN               NaN             NaN
# 6   TH155_E5                 EGFR             del19             NaN
# 7   TH172_E3                  NaN               NaN             NaN
# 8   TH169_E4                 EGFR             del19             NaN
# 9   TH220_E2                  ALK            fusion             NaN
# 10  TH067_E7                 EGFR             del19             NaN
# 11  TH169_E2                 EGFR             del19             NaN
# 12  TH208_E4                  NaN               NaN             NaN
# ...

# %%
def translated_muts_fill_in_egfr(summaryTable_):
    """ converts 'raw' mutation calls to something that more resembles
        those reported in our clinical cols. egfr, specificially """
    for i in range(0,len(summaryTable_.index)):
        translatedList = []
        currPatient = summaryTable_['patient'].iloc[i]
        currMuts_egfr = summaryTable_['mutations_found_EGFR'].iloc[i]
        currMuts_egfr_split = currMuts_egfr.split(',')
        for item in currMuts_egfr_split:
            if 'delELR' in item:
                translatedList.append('EGFR del19')
            elif '745_' in item:
                translatedList.append('EGFR del19')
            elif '746_' in item:
                translatedList.append('EGFR del19')
            elif 'ins' in item:
                translatedList.append('EGFR ins20')
            elif item != '':
                translatedList.append('EGFR ' + item)
        
        summaryTable_['mutations_found_translated'][i] = translatedList

# %%
# set up a col to translate 'raw' mutation calls to 'clinical'
summaryTable['mutations_found_translated'] = ""
translated_muts_fill_in_egfr(summaryTable)
summaryTable
# Out:
#      patient clinical_driver_gene clinical_mutation coverage_to_ROI  \
# 0   TH171_E3                  ALK            fusion             NaN
# 1   TH116_E2                  NaN               NaN             NaN
# 2   TH179_E1                 BRAF             V600E             NaN
# 3   TH231_E1                  ALK            fusion             NaN
# 4   TH226_E3                 EGFR             del19             NaN
# 5   TH187_E3                  NaN               NaN             NaN
# 6   TH155_E5                 EGFR             del19             NaN
# 7   TH172_E3                  NaN               NaN             NaN
# 8   TH169_E4                 EGFR             del19             NaN
# 9   TH220_E2                  ALK            fusion             NaN
# 10  TH067_E7                 EGFR             del19             NaN
# 11  TH169_E2                 EGFR             del19             NaN
# 12  TH208_E4                  NaN               NaN             NaN
# ...

# %%
def translated_muts_fill_in(GOI, summaryTable_):
    """ converts 'raw' mutation calls to something that more resembles
        those reported in our clinical cols. general """
    colName = 'mutations_found_' + GOI
    for i in range(0,len(summaryTable_.index)):
        translatedList = []
        currPatient = summaryTable_['patient'].iloc[i]
        currMuts = summaryTable_[colName].iloc[i]
        currMuts_split = currMuts.split(',')
        for item in currMuts_split:
            if item != '' and '?' not in item:
                translatedList.append(GOI + ' ' + item)

        summaryTable_['mutations_found_translated'][i] = summaryTable_['mutations_found_translated'][i] + translatedList

# %%
# translate the rest of 'em
for gene in genesList:
    translated_muts_fill_in(gene, summaryTable)

summaryTable
# Out:
#      patient clinical_driver_gene clinical_mutation coverage_to_ROI  \
# 0   TH171_E3                  ALK            fusion             NaN
# 1   TH116_E2                  NaN               NaN             NaN
# 2   TH179_E1                 BRAF             V600E             NaN
# 3   TH231_E1                  ALK            fusion             NaN
# 4   TH226_E3                 EGFR             del19             NaN
# 5   TH187_E3                  NaN               NaN             NaN
# 6   TH155_E5                 EGFR             del19             NaN
# 7   TH172_E3                  NaN               NaN             NaN
# 8   TH169_E4                 EGFR             del19             NaN
# 9   TH220_E2                  ALK            fusion             NaN
# 10  TH067_E7                 EGFR             del19             NaN
# 11  TH169_E2                 EGFR             del19             NaN
# 12  TH208_E4                  NaN               NaN             NaN
# ...

# %%
def convert_to_string(summaryTable_):
    """ converting mutations_found_translated col from list to str. """
    for i in range(0,len(summaryTable_.index)):
        currStr = str(summaryTable_['mutations_found_translated'][i])
        currStr = currStr.replace("'", "")
        currStr = currStr.replace("]", "")
        currStr = currStr.replace("[", "")
        summaryTable_['mutations_found_translated'][i] = currStr

# %%
# convert lists to strs, so i can get set -- probably not necessary
convert_to_string(summaryTable)
summaryTable['mutations_found_translated']
# Out:
# 0
# 1                    EGFR L858R, EGFR L858R, EGFR L858R
# 2     BRAF V600E, MAP2K2 G182G, BRAF V600E, MAP2K2 G...
# 3
# 4     EGFR del19, EGFR del19, EGFR E746_A750delELREA...
# 5
# 6                    EGFR K754E, EGFR K754E, EGFR K754E
# 7
# 8     EGFR del19, EGFR del19, EGFR E746_A750delELREA...
# 9
# 10    EGFR del19, EGFR del19, EGFR E746_T751delELREA...
# 11    EGFR del19, EGFR del19, EGFR E746_A750delELREA...
# 12                   EGFR L861Q, EGFR L861Q, EGFR L861Q
# 13
# 14
# 15    EGFR del19, EGFR del19, EGFR E746_T751delELREA...
# 16
# 17                   EGFR L861Q, EGFR L861Q, EGFR L861Q
# Name: mutations_found_translated, dtype: object

# %%
set(summaryTable['mutations_found_translated'])
# Out:
# {'',
#  'BRAF V600E, MAP2K2 G182G, BRAF V600E, MAP2K2 G182G',
#  'EGFR K754E, EGFR K754E, EGFR K754E',
#  'EGFR L858R, EGFR L858R, EGFR L858R',
#  'EGFR L861Q, EGFR L861Q, EGFR L861Q',
#  'EGFR del19, EGFR del19, EGFR E746_A750delELREA, EGFR E746_T751delELREAT, EGFR E746_A750delELREA, EGFR E746_T751delELREAT',
#  'EGFR del19, EGFR del19, EGFR E746_T751delELREAT, EGFR E746_S752>D, EGFR E746_T751delELREAT, EGFR E746_S752>D'}

# %%
# fill in clin_mut_found_bool 
summarize_module.clin_mut_found_fill_in(summaryTable)
summarize_module.clin_mut_found_fill_in_fus(summaryTable)
